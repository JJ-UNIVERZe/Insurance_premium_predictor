# %%
import pandas as pd

df = pd.read_csv("data/travel_augmented.csv")
df.head()
# Out:
#    age  gender mode_of_transport  trip_length_days destination_risk  \
# 0   56  Female             Train                22              Low
# 1   69  Female             Train                 1              Low
# 2   46  Female            Flight                16           Medium
# 3   32  Female             Train                10              Low
# 4   60    Male            Flight                26           Medium
#
#   travel_purpose  coverage_amount  deductible  previous_claims_count  \
# 0      Adventure             5000         100                      1
# 1       Business             5000         200                      0
# 2       Business            20000         200                      1
# 3      Adventure             5000         100                      0
# 4        Leisure             1000         200                      0
#
#   has_preexisting_conditions  claim_occurred  claim_amount
# 0                        Yes               0           0.0
# ...

# %%
df.info()   # column types, nulls
df.describe(include='all')  # numeric + categorical summary
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 13000 entries, 0 to 12999
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   age                         13000 non-null  int64
#  1   gender                      13000 non-null  object
#  2   mode_of_transport           13000 non-null  object
#  3   trip_length_days            13000 non-null  int64
#  4   destination_risk            13000 non-null  object
#  5   travel_purpose              13000 non-null  object
#  6   coverage_amount             13000 non-null  int64
#  7   deductible                  13000 non-null  int64
#  8   previous_claims_count       13000 non-null  int64
#  9   has_preexisting_conditions  13000 non-null  object
#  10  claim_occurred              13000 non-null  int64
#  11  claim_amount                13000 non-null  float64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 1.2+ MB
# ...

# %%
df['claim_occurred'].value_counts(normalize=True)
# Out:
# claim_occurred
# 0    0.962462
# 1    0.037538
# Name: proportion, dtype: float64

# %%
pip install matplotlib seaborn
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Claim amount distribution
sns.histplot(df['claim_amount'], bins=50, kde=True)
plt.title("Claim Amount Distribution")
plt.show()

# Trip length distribution
sns.histplot(df['trip_length_days'], bins=30, kde=False)
plt.title("Trip Length Distribution")
plt.show()

# Age distribution
sns.histplot(df['age'], bins=30, kde=False)
plt.title("Age Distribution")
plt.show()

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()
